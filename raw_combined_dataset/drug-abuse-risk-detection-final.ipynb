# %%
import pandas as pd

df_train = pd.read_csv("E:/Projects/Drug-Abuse-Risk-Detection/drug-abuse-risk-detection/Students drugs Addiction Dataset/Student_Drugs_Addiction_Training_ Dataset/student_addiction_dataset_train.csv")
df_test = pd.read_csv("E:/Projects/Drug-Abuse-Risk-Detection/drug-abuse-risk-detection/Students drugs Addiction Dataset/Student_Drugs_Addiction_Testing_ Dataset/student_addiction_dataset_test.csv")

full_df = pd.concat([df_train, df_test], axis=0, ignore_index=True)

print(full_df.shape)
# Out:
# (63086, 11)

# %%
full_df.to_csv("E:/Projects/Drug-Abuse-Risk-Detection/raw_combined_dataset/combined.csv")
print("Dataset Created")
# Out:
# Dataset Created
